# %%
import pandas as pd

# %%
df = pd.read_csv("data/matches.csv")

# %%
df.tail(10)
# Out:
#       match_id  season_id  balls_per_over            city        date  \
# 1200   2026032       2026               6         Lucknow  2026-04-22
# 1201   2026033       2026               6          Mumbai  2026-04-23
# 1202   2026034       2026               6       Bengaluru  2026-04-24
# 1203   2026036       2026               6          Jaipur  2026-04-25
# 1204   2026035       2026               6           Delhi  2026-04-25
# 1205   2026038       2026               6         Lucknow  2026-04-26
# 1206   2026037       2026               6         Chennai  2026-04-26
# 1207   2026039       2026               6           Delhi  2026-04-27
# 1208   2026040       2026               6  New Chandigarh  2026-04-28
# 1209   2026041       2026               6          Mumbai  2026-04-29
#
#                  event_name  match_number gender match_type format  ...  \
# 1200  Indian Premier League          32.0   male        T20    T20  ...
# ...
